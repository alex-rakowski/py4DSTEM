# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

# %%
import py4DSTEM

# %%
py4DSTEM.hello()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 py4DSTEM.hello()
#
# AttributeError: module 'py4DSTEM' has no attribute 'hello'

# %%
import matplotlib.pyplot as plt

# %%
import py4DSTEM

# %%
x = np.random.random((64,64))

# %%
py4DSTEM.show(x)

# %%
plt.imshow(x)

# %%
py4DSTEM.show(x)

# %%
py4DSTEM.show(x)

# %%
p

# %%
x

# %%
x = 'shift'
x is not 'shift'
# Out:
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /tmp/ipykernel_8243/1985519730.py:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   x is not 'shift'
# False
